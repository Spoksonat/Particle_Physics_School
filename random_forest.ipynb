# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split # Machine learning packages
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %% [markdown]
# ### Preparación de datos ( Ignorar :) )

# %%
column_names = ["bjets[0].Pt()", "bjets[1].Pt()", "bjets[2].Pt()", "bjets[3].Pt()", "(bjets[0].Eta() - bjets[1].Eta())", "(bjets[0].Eta() - bjets[2].Eta())", "(bjets[0].Eta() - bjets[3].Eta())", 
"(bjets[1].Eta() - bjets[2].Eta())", "(bjets[1].Eta() - bjets[3].Eta())", "(bjets[2].Eta() - bjets[3].Eta())", "bjets[0].DeltaPhi(bjets[1])", "bjets[0].DeltaPhi(bjets[2])", "bjets[0].DeltaPhi(bjets[3])", 
"bjets[1].DeltaPhi(bjets[2])", "bjets[1].DeltaPhi(bjets[3])", "bjets[2].DeltaPhi(bjets[3])","bjets[0].DeltaR(bjets[1])", "bjets[0].DeltaR(bjets[2])", "bjets[0].DeltaR(bjets[3])", 
"bjets[1].DeltaR(bjets[2])", "bjets[1].DeltaR(bjets[3])", "bjets[2].DeltaR(bjets[3])", "MET.Pt()", "np.sum(np.array(leptons)).Pt()", "(leptons_tot + MET).Mt()", "(bjets[0] + bjets[1]).M()", 
"(bjets[0] + bjets[2]).M()", "(bjets[0] + bjets[3]).M()", "(bjets[1] + bjets[2]).M()", "(bjets[1] + bjets[3]).M()", "(bjets[2] + bjets[3]).M()", "(bjets[0] + leptons_tot + MET).Mt()", 
"(bjets[1] + leptons_tot + MET).Mt()", "(bjets[2] + leptons_tot + MET).Mt()", "(bjets[3] + leptons_tot + MET).Mt()", "(jets[0] + jets[1]).M()", "jets[0].Pt()", "jets[1].Pt()", "jets[0].DeltaR(jets[1])",
 "bjets[0].DeltaR(leptons_tot)", "bjets[1].DeltaR(leptons_tot)", "bjets[2].DeltaR(leptons_tot)", "bjets[3].DeltaR(leptons_tot)", "bjets[0].DeltaPhi(leptons_tot)", "bjets[1].DeltaPhi(leptons_tot)", 
 "bjets[2].DeltaPhi(leptons_tot)", "bjets[3].DeltaPhi(leptons_tot)", "bjets[0].Phi", "bjets[1].Phi", "bjets[0].Eta", "bjets[1].Eta", "jets[0].Phi", "jets[1].Phi", "jets[0].Eta", "jets[1].Eta", 
 "leptons_tot.Phi", "leptons_tot.Eta", "class", "type"]

dfs1, dfs2, dfs3 = pd.read_csv("signal250.txt", names=column_names, sep=" "), pd.read_csv("signal350.txt", names=column_names, sep=" "), pd.read_csv("signal1000.txt", names=column_names, sep=" ")
dfb1, dfb2, dfb3 = pd.read_csv("bkg1.txt", names=column_names, sep=" "), pd.read_csv("bkg2.txt", names=column_names, sep=" "), pd.read_csv("bkg3.txt", names=column_names, sep=" ")

dfs1["class"], dfs2["class"], dfs3["class"], dfb1["class"], dfb2["class"], dfb3["class"] = 1, 1, 1, 0, 0, 0
dfs1["type"], dfs2["type"], dfs3["type"], dfb1["type"], dfb2["type"], dfb3["type"] = "sgn1", "sgn2", "sgn3", "bkg1", "bkg2", "bkg3"

df = pd.concat([dfs1, dfs2, dfs3, dfb1, dfb2, dfb3], ignore_index=True)

dataprime = pd.concat([df.iloc[:,:47], df.iloc[:,-2:]], axis=1)
s1 = dataprime.loc[dataprime["type"] == "sgn1"]
s2 = dataprime.loc[dataprime["type"] == "sgn2"]
s3 = dataprime.loc[dataprime["type"] == "sgn3"]
b1 = dataprime.loc[dataprime["type"] == "bkg1"]
b2 = dataprime.loc[dataprime["type"] == "bkg2"]
b3 = dataprime.loc[dataprime["type"] == "bkg3"]

frames1, frames2, frames3 = [s1, b1.iloc[:int(len(s1.index)/3.0), :], b2.iloc[:int(len(s1.index)/3.0), :], b3.iloc[:int(len(s1.index)/3.0), :]], [s2, b1.iloc[:int(len(s2.index)/3.0), :], b2.iloc[:int(len(s2.index)/3.0), :], b3.iloc[:int(len(s2.index)/3.0), :]], [s3, b1.iloc[:int(len(s3.index)/3.0), :], b2.iloc[:int(len(s3.index)/3.0), :], b3.iloc[:int(len(s3.index)/3.0), :]]

datap1, datap2, datap3 = pd.concat(frames1), pd.concat(frames2), pd.concat(frames3)

datap1
# Out:
#        bjets[0].Pt()  bjets[1].Pt()  bjets[2].Pt()  bjets[3].Pt()  \
# 0          85.790062      79.101341      76.226639      73.484489
# 1         199.395157      64.486130      57.019939      49.212360
# 2         108.240120     107.411797     102.838387      40.021046
# 3         190.237045      96.510109      69.834419      63.006943
# 4         221.238800     118.019905      56.416767      33.174603
# ...              ...            ...            ...            ...
# 97890     255.430542     122.749817     116.968292     110.687889
# 97891     124.438179      65.141716      53.507172      52.842712
# 97892      78.006691      49.945076      46.788639      40.991722
# 97893     368.648376     149.937195      65.914497      33.615135
# 97894     128.559158      69.980110      46.797848      30.015293
#
#        (bjets[0].Eta() - bjets[1].Eta())  (bjets[0].Eta() - bjets[2].Eta())  \
# 0                              -1.834188                          -0.672529
# 1                              -0.730201                           0.452975
# 2                               1.543365                          -0.485863
# 3                               0.146976                          -1.331831
# 4                               1.265345                           0.453719
# ...                                  ...                                ...
# 97890                          -1.704186                          -1.900271
# 97891                           0.076654                          -0.476945
# 97892                           2.558095                           2.067611
# 97893                          -1.843894                          -1.221882
# 97894                           2.036174                           0.454317
#
#        (bjets[0].Eta() - bjets[3].Eta())  (bjets[1].Eta() - bjets[2].Eta())  \
# 0                              -1.763499                           1.161659
# 1                              -1.372216                           1.183176
# 2                              -1.095197                          -2.029228
# 3                               0.458187                          -1.478806
# 4                               1.305476                          -0.811625
# ...                                  ...                                ...
# 97890                          -1.173590                          -0.196086
# 97891                          -0.503437                          -0.553599
# 97892                           1.586548                          -0.490484
# 97893                          -0.370761                           0.622013
# 97894                           3.323938                          -1.581857
#
#        (bjets[1].Eta() - bjets[3].Eta())  (bjets[2].Eta() - bjets[3].Eta())  \
# 0                               0.070688                          -1.090971
# 1                              -0.642015                          -1.825191
# 2                              -2.638563                          -0.609334
# 3                               0.311212                           1.790018
# 4                               0.040131                           0.851757
# ...                                  ...                                ...
# 97890                           0.530596                           0.726682
# 97891                          -0.580090                          -0.026491
# 97892                          -0.971547                          -0.481062
# 97893                           1.473134                           0.851121
# 97894                           1.287764                           2.869621
#
#        ...  bjets[0].DeltaR(leptons_tot)  bjets[1].DeltaR(leptons_tot)  \
# 0      ...                      2.651338                      0.918119
# 1      ...                      0.707457                      2.552826
# 2      ...                      1.069924                      2.152137
# 3      ...                      2.163157                      2.493140
# 4      ...                      3.201904                      2.018901
# ...    ...                           ...                           ...
# 97890  ...                      2.807700                      2.004631
# 97891  ...                      1.920514                      3.141797
# 97892  ...                      1.427355                      2.232073
# 97893  ...                      2.069372                      2.018015
# 97894  ...                      1.980221                      3.593239
#
#        bjets[2].DeltaR(leptons_tot)  bjets[3].DeltaR(leptons_tot)  \
# 0                          1.369247                      1.887533
# 1                          0.794673                      2.405341
# 2                          2.105191                      3.017604
# 3                          4.210813                      2.640569
# 4                          1.262092                      2.237806
# ...                             ...                           ...
# 97890                      1.085945                      0.517018
# 97891                      2.038115                      2.866478
# 97892                      1.506408                      1.872301
# 97893                      2.317998                      2.173683
# 97894                      1.325933                      5.013395
#
#        bjets[0].DeltaPhi(leptons_tot)  bjets[1].DeltaPhi(leptons_tot)  \
# 0                            2.073459                       -0.899938
# 1                            0.238163                       -2.137074
# 2                            1.017498                        1.057904
# 3                            1.033992                       -1.772724
# 4                            3.115782                       -0.253111
# ...                               ...                             ...
# 97890                        2.686027                       -1.797910
# 97891                        1.750042                       -3.059503
# 97892                       -1.068632                       -1.544043
# 97893                       -1.907863                        1.727930
# 97894                       -1.790771                       -2.146830
#
#        bjets[2].DeltaPhi(leptons_tot)  bjets[3].DeltaPhi(leptons_tot)  class  \
# 0                            0.956414                        1.884259      1
# 1                            0.765543                       -1.276979      1
# 2                           -2.099474                       -2.919185      1
# 3                            2.699264                       -2.212170      1
# 4                           -0.416616                       -0.912963      1
# ...                               ...                             ...    ...
# 97890                        0.084041                       -0.374923      0
# 97891                       -1.595669                        2.557550      0
# 97892                        1.005878                        1.759407      0
# 97893                        2.279556                        2.130583      0
# 97894                        0.263206                       -2.784271      0
#
#        type
# 0      sgn1
# 1      sgn1
# 2      sgn1
# 3      sgn1
# 4      sgn1
# ...     ...
# 97890  bkg3
# 97891  bkg3
# 97892  bkg3
# 97893  bkg3
# 97894  bkg3
#
# [37520 rows x 49 columns]

# %% [markdown]
# ### Separamos los datos de sus respectivas clases asociadas

# %%
data1, data2, data3 = datap1.iloc[:,:47], datap2.iloc[:,:47], datap3.iloc[:,:47]
target1, target2, target3 = datap1.iloc[:,-2], datap2.iloc[:,-2], datap3.iloc[:,-2]

# %% [markdown]
# ### Separamos nuestros datos entre datos de entrenamiento (75%) y datos de prueba (25%)

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(data1, target1, test_size=0.25, random_state=0) # 0.25 significa 25% de los datos. Si es entero, representa numero de test samples
x_train2, x_test2, y_train2, y_test2 = train_test_split(data2, target2, test_size=0.25, random_state=0) # tambien se puede especificar el train_size
x_train3, x_test3, y_train3, y_test3 = train_test_split(data3, target3, test_size=0.25, random_state=0)

# %% [markdown]
# ### Entrenamos los tres modelos

# %%
rf1 = RandomForestClassifier(n_estimators=100) # n_estimators = numero de arboles en el bosque aleatorio. Ver: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
rf1.fit(x_train1, y_train1)

rf2 = RandomForestClassifier(n_estimators=100) 
rf2.fit(x_train2, y_train2)

rf3 = RandomForestClassifier(n_estimators=100) 
rf3.fit(x_train3, y_train3)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ### Encontramos valores de precision y recall para los tres modelos

# %%
predictions1, predictions2, predictions3 = rf1.predict(x_test1), rf2.predict(x_test2), rf3.predict(x_test3)

precision1, precision2, precision3  = precision_score(y_test1, predictions1, average='micro'), precision_score(y_test2, predictions2, average='micro'), precision_score(y_test3, predictions3, average='micro')

recall1, recall2, recall3 = recall_score(y_test1, predictions1, average='micro'), recall_score(y_test2, predictions2, average='micro'), recall_score(y_test3, predictions3, average='micro')


print("The precision for the first model is: ", precision1)
print("The precision for the second model is: ", precision2)
print("The precision for the third model is: ", precision3)
print("\n")
print("The recall for the first model is: ", recall1)
print("The recall for the second model is: ", recall2)
print("The recall for the third model is: ", recall3)
# Out:
# The precision for the first model is:  0.6445628997867804
# The precision for the second model is:  0.6864959594976147
# The precision for the third model is:  0.8869383153486874
#
#
# The recall for the first model is:  0.6445628997867804
# The recall for the second model is:  0.6864959594976147
# The recall for the third model is:  0.8869383153486874

# %% [markdown]
# ### Encontramos las matrices de confusion

# %%
cm1, cm2, cm3 = metrics.confusion_matrix(y_test1, predictions1), metrics.confusion_matrix(y_test2, predictions2), metrics.confusion_matrix(y_test3, predictions3) 
print("Confusion matrix for the first model is: ")
print(cm1)
print("Confusion matrix for the second model is: ")
print(cm2)
print("Confusion matrix for the third model is: ")
print(cm3)

plt.figure(figsize=(9,9))
sns.heatmap(cm1, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = "RdYlGn", cbar=True, annot_kws={"fontsize":25, "color":"k"})
plt.ylabel('DATA', fontsize=20)
plt.xlabel('PREDICTION', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
all_sample_title = 'Accuracy Score: {0}'.format(format(recall1, ".3f"))
plt.title(all_sample_title, size = 20)

plt.figure(figsize=(9,9))
sns.heatmap(cm2, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = "RdYlGn", cbar=True, annot_kws={"fontsize":25, "color":"k"})
plt.ylabel('DATA', fontsize=20)
plt.xlabel('PREDICTION', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
all_sample_title = 'Accuracy Score: {0}'.format(format(recall2, ".3f"))
plt.title(all_sample_title, size = 20)

plt.figure(figsize=(9,9))
sns.heatmap(cm3, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = "RdYlGn", cbar=True, annot_kws={"fontsize":25, "color":"k"})
plt.ylabel('DATA', fontsize=20)
plt.xlabel('PREDICTION', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
all_sample_title = 'Accuracy Score: {0}'.format(format(recall3, ".3f"))
plt.title(all_sample_title, size = 20)
# Out:
# Confusion matrix for the first model is:
# [[3077 1649]
#  [1685 2969]]
# Confusion matrix for the second model is:
# [[3447 1742]
#  [1478 3604]]
# Confusion matrix for the third model is:
# [[2669  436]
#  [ 266 2838]]
# Text(0.5, 1.0, 'Accuracy Score: 0.887')

# %% [markdown]
# ### Importancia de cada variable (solo para tercer modelo)

# %%
importance3 = rf3.feature_importances_

for i,s in enumerate(importance3):
    print('Feature: %0s, Score: %.5f' % (column_names[i],s))
# Out:
# Feature: bjets[0].Pt(), Score: 0.15953
# Feature: bjets[1].Pt(), Score: 0.10491
# Feature: bjets[2].Pt(), Score: 0.04105
# Feature: bjets[3].Pt(), Score: 0.01165
# Feature: (bjets[0].Eta() - bjets[1].Eta()), Score: 0.01044
# Feature: (bjets[0].Eta() - bjets[2].Eta()), Score: 0.00858
# Feature: (bjets[0].Eta() - bjets[3].Eta()), Score: 0.00770
# Feature: (bjets[1].Eta() - bjets[2].Eta()), Score: 0.00751
# Feature: (bjets[1].Eta() - bjets[3].Eta()), Score: 0.00731
# Feature: (bjets[2].Eta() - bjets[3].Eta()), Score: 0.00729
# Feature: bjets[0].DeltaPhi(bjets[1]), Score: 0.00874
# Feature: bjets[0].DeltaPhi(bjets[2]), Score: 0.00788
# Feature: bjets[0].DeltaPhi(bjets[3]), Score: 0.00715
# Feature: bjets[1].DeltaPhi(bjets[2]), Score: 0.00774
# Feature: bjets[1].DeltaPhi(bjets[3]), Score: 0.00762
# Feature: bjets[2].DeltaPhi(bjets[3]), Score: 0.00724
# Feature: bjets[0].DeltaR(bjets[1]), Score: 0.01477
# Feature: bjets[0].DeltaR(bjets[2]), Score: 0.01057
# Feature: bjets[0].DeltaR(bjets[3]), Score: 0.00940
# Feature: bjets[1].DeltaR(bjets[2]), Score: 0.00949
# Feature: bjets[1].DeltaR(bjets[3]), Score: 0.00877
# Feature: bjets[2].DeltaR(bjets[3]), Score: 0.00759
# Feature: MET.Pt(), Score: 0.00979
# Feature: np.sum(np.array(leptons)).Pt(), Score: 0.00847
# Feature: (leptons_tot + MET).Mt(), Score: 0.00682
# Feature: (bjets[0] + bjets[1]).M(), Score: 0.13981
# Feature: (bjets[0] + bjets[2]).M(), Score: 0.06809
# Feature: (bjets[0] + bjets[3]).M(), Score: 0.04285
# Feature: (bjets[1] + bjets[2]).M(), Score: 0.03919
# Feature: (bjets[1] + bjets[3]).M(), Score: 0.02293
# Feature: (bjets[2] + bjets[3]).M(), Score: 0.01358
# Feature: (bjets[0] + leptons_tot + MET).Mt(), Score: 0.01767
# Feature: (bjets[1] + leptons_tot + MET).Mt(), Score: 0.01170
# Feature: (bjets[2] + leptons_tot + MET).Mt(), Score: 0.00842
# Feature: (bjets[3] + leptons_tot + MET).Mt(), Score: 0.00665
# Feature: (jets[0] + jets[1]).M(), Score: 0.01107
# Feature: jets[0].Pt(), Score: 0.03409
# Feature: jets[1].Pt(), Score: 0.01302
# Feature: jets[0].DeltaR(jets[1]), Score: 0.00827
# Feature: bjets[0].DeltaR(leptons_tot), Score: 0.00863
# Feature: bjets[1].DeltaR(leptons_tot), Score: 0.00979
# Feature: bjets[2].DeltaR(leptons_tot), Score: 0.00796
# Feature: bjets[3].DeltaR(leptons_tot), Score: 0.00803
# Feature: bjets[0].DeltaPhi(leptons_tot), Score: 0.00792
# Feature: bjets[1].DeltaPhi(leptons_tot), Score: 0.00757
# Feature: bjets[2].DeltaPhi(leptons_tot), Score: 0.00745
# Feature: bjets[3].DeltaPhi(leptons_tot), Score: 0.00730

# %%
plt.bar([x for x in range(len(importance3))], importance3)
# Out:
# <BarContainer object of 47 artists>
